# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests
import json
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %% [markdown]
# ## Part 1

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
result = requests.get(url).content
soup = BeautifulSoup(result, 'html.parser')

table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

cols = ['PostalCode', 'Borough', 'Neighborhood']
df=pd.DataFrame(table_contents, columns=cols)
print(df.shape)
# Out:
# (103, 3)

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a676c3d8c05> in <module>()
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Part 2

# %%
df = df.groupby('PostalCode').agg(
    {
        'Borough':'first', 
        'Neighborhood': ', '.join,}
    ).reset_index()
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Coordinates of the Neighborhood

# %%
#cant get geocoder.google to work so using csv file
# !wget -O GeoCord.csv http://cocl.us/Geospatial_data/
df_latlong = pd.read_csv('Geospatial_Coordinates.csv') # Read the csv data
df_latlong.head()
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Create new columns in df
df['Latitude'] = np.nan
df['Longitude'] = np.nan

# For each postcode in df_cord, find corresponding coordinates in df_cord and assign it to df_assigned
for idx in df.index:
    c_idx = df_latlong['Postal Code'] == df.loc[idx, 'PostalCode']
    df.at[idx, 'Latitude'] = df_latlong.loc[c_idx, 'Latitude'].values
    df.at[idx, 'Longitude'] = df_latlong.loc[c_idx, 'Longitude'].values
# Out:
#     PostalCode                                            Borough  \
# 0          M1B                                        Scarborough
# 1          M1C                                        Scarborough
# 2          M1E                                        Scarborough
# 3          M1G                                        Scarborough
# 4          M1H                                        Scarborough
# 5          M1J                                        Scarborough
# 6          M1K                                        Scarborough
# 7          M1L                                        Scarborough
# 8          M1M                                        Scarborough
# 9          M1N                                        Scarborough
# 10         M1P                                        Scarborough
# 11         M1R                                        Scarborough
# 12         M1S                                        Scarborough
# 13         M1T                                        Scarborough
# 14         M1V                                        Scarborough
# 15         M1W                                        Scarborough
# 16         M1X                                        Scarborough
# 17         M2H                                         North York
# 18         M2J                                         North York
# 19         M2K                                         North York
# 20         M2L                                         North York
# 21         M2M                                         North York
# 22         M2N                                         North York
# 23         M2P                                         North York
# 24         M2R                                         North York
# 25         M3A                                         North York
# 26         M3B                                         North York
# 27         M3C                                         North York
# 28         M3H                                         North York
# 29         M3J                                         North York
# ..         ...                                                ...
# 73         M6C                                               York
# 74         M6E                                               York
# 75         M6G                                   Downtown Toronto
# 76         M6H                                       West Toronto
# 77         M6J                                       West Toronto
# 78         M6K                                       West Toronto
# 79         M6L                                         North York
# 80         M6M                                               York
# 81         M6N                                               York
# 82         M6P                                       West Toronto
# 83         M6R                                       West Toronto
# 84         M6S                                       West Toronto
# 85         M7A                                       Queen's Park
# 86         M7R   MississaugaCanada Post Gateway Processing Centre
# 87         M7Y  East TorontoBusiness reply mail Processing Cen...
# 88         M8V                                          Etobicoke
# 89         M8W                                          Etobicoke
# 90         M8X                                          Etobicoke
# 91         M8Y                                          Etobicoke
# 92         M8Z                                          Etobicoke
# 93         M9A                                          Etobicoke
# 94         M9B                                          Etobicoke
# 95         M9C                                          Etobicoke
# 96         M9L                                         North York
# 97         M9M                                         North York
# 98         M9N                                               York
# 99         M9P                                          Etobicoke
# 100        M9R                                          Etobicoke
# 101        M9V                                          Etobicoke
# 102        M9W                                 EtobicokeNorthwest
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 7                      Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 8      Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 9                          Birch Cliff, Cliffside West  43.692657 -79.264848
# 10   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 11                                   Wexford, Maryvale  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 14   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 15                       Steeles West, L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            York Mills, Silver Hills  43.757490 -79.374714
# 21                             Willowdale, Newtonbrook  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                                     Don Mills South  43.725900 -79.340923
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 79            North Park, Maple Leaf Park, Upwood Park  43.713756 -79.490074
# 80    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 81                       Runnymede, The Junction North  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Runnymede, Swansea  43.651571 -79.484450
# 85                       Ontario Provincial Government  43.662301 -79.389494
# 86                                      Enclave of L4W  43.636966 -79.615819
# 87                                      Enclave of M4L  43.662744 -79.321558
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89                              Alderwood, Long Branch  43.602414 -79.543484
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 91   Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 92   Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 95   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Humberlea, Emery  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 102  Clairville, Humberwood, Woodbine Downs, West H...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
df.head(50)
# Out:
#    PostalCode                Borough  \
# 0         M1B            Scarborough
# 1         M1C            Scarborough
# 2         M1E            Scarborough
# 3         M1G            Scarborough
# 4         M1H            Scarborough
# 5         M1J            Scarborough
# 6         M1K            Scarborough
# 7         M1L            Scarborough
# 8         M1M            Scarborough
# 9         M1N            Scarborough
# 10        M1P            Scarborough
# 11        M1R            Scarborough
# 12        M1S            Scarborough
# 13        M1T            Scarborough
# 14        M1V            Scarborough
# 15        M1W            Scarborough
# 16        M1X            Scarborough
# 17        M2H             North York
# 18        M2J             North York
# 19        M2K             North York
# 20        M2L             North York
# 21        M2M             North York
# 22        M2N             North York
# 23        M2P             North York
# 24        M2R             North York
# 25        M3A             North York
# 26        M3B             North York
# 27        M3C             North York
# 28        M3H             North York
# 29        M3J             North York
# 30        M3K             North York
# 31        M3L             North York
# 32        M3M             North York
# 33        M3N             North York
# 34        M4A             North York
# 35        M4B              East York
# 36        M4C              East York
# 37        M4E           East Toronto
# 38        M4G              East York
# 39        M4H              East York
# 40        M4J  East YorkEast Toronto
# 41        M4K           East Toronto
# 42        M4L           East Toronto
# 43        M4M           East Toronto
# 44        M4N        Central Toronto
# 45        M4P        Central Toronto
# 46        M4R        Central Toronto
# 47        M4S        Central Toronto
# 48        M4T        Central Toronto
# 49        M4V        Central Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                      Malvern, Rouge  43.806686 -79.194353
# 1              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                 Scarborough Village  43.744734 -79.239476
# 6         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 7                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 8     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 9                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 10  Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 11                                  Wexford, Maryvale  43.750072 -79.295849
# 12                                          Agincourt  43.794200 -79.262029
# 13            Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 14  Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 15                      Steeles West, L'Amoreaux West  43.799525 -79.318389
# 16                                        Upper Rouge  43.836125 -79.205636
# 17                                  Hillcrest Village  43.803762 -79.363452
# 18                       Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 19                                    Bayview Village  43.786947 -79.385975
# 20                           York Mills, Silver Hills  43.757490 -79.374714
# 21                            Willowdale, Newtonbrook  43.789053 -79.408493
# 22                                   Willowdale South  43.770120 -79.408493
# 23                                    York Mills West  43.752758 -79.400049
# 24                                    Willowdale West  43.782736 -79.442259
# 25                                          Parkwoods  43.753259 -79.329656
# 26                                    Don Mills North  43.745906 -79.352188
# 27                                    Don Mills South  43.725900 -79.340923
# 28    Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 29                    Northwood Park, York University  43.767980 -79.487262
# 30                                     Downsview East  43.737473 -79.464763
# 31                                     Downsview West  43.739015 -79.506944
# 32                                  Downsview Central  43.728496 -79.495697
# 33                                Downsview Northwest  43.761631 -79.520999
# 34                                   Victoria Village  43.725882 -79.315572
# 35                    Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 36                                   Woodbine Heights  43.695344 -79.318389
# 37                                        The Beaches  43.676357 -79.293031
# 38                                            Leaside  43.709060 -79.363452
# 39                                   Thorncliffe Park  43.705369 -79.349372
# 40                                 The Danforth  East  43.685347 -79.338106
# 41                       The Danforth West, Riverdale  43.679557 -79.352188
# 42                     India Bazaar, The Beaches West  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 44                                      Lawrence Park  43.728020 -79.388790
# 45                                   Davisville North  43.712751 -79.390197
# 46                                 North Toronto West  43.715383 -79.405678
# 47                                         Davisville  43.704324 -79.388790
# 48                        Moore Park, Summerhill East  43.689574 -79.383160
# 49  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049

# %%
df.loc[df['PostalCode'] == 'M4T']
# Out:
#    PostalCode          Borough                 Neighborhood   Latitude  \
# 48        M4T  Central Toronto  Moore Park, Summerhill East  43.689574
#
#     Longitude
# 48  -79.38316

# %% [markdown]
# ## Toronto Map

# %%
geoloc = Nominatim(user_agent="coursera")
address = 'Toronto'
try:
    location = geoloc.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinates of {} are {}, {}.'.format(address, latitude, longitude))
except AttributeError:
    print('Cannot find: {}, will drop index: {}'.format(address, index))

Tmap = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['PostalCode']):
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(Tmap)  
    
Tmap
# Out:
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5c3c0d6d4b8e4ebf8208667e22230a76%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5c3c0d6d4b8e4ebf8208667e22230a76%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5c3c0d6d4b8e4ebf8208667e22230a76%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5c3c0d6d4b8e4ebf8208667e22230a76%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Using Foursquare to Analyze location

# %%
CLIENT_ID = '2ZN3TPSTZ2YHCDFULTDGFVGBX1YJL45HQ0LD3RCFOEMXCMM5' # ID
CLIENT_SECRET = '3KYZWRDZC3JJNDBOS5V1MPTYUZPMGKNRI0CMKLHR125T0NHW' # Secret
VERSION = '20210508'

# %%
CT_latitude = df.loc[48]['Latitude']
CT_longitude = df.loc[48]['Longitude']

# %%
CT_latitude
# Out:
# 43.6895743

# %%
CT_longitude
# Out:
# -79.38315990000001

# %%
LIMIT = 100 # limit to number of venues
radius = 600 # defining scope
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    CT_latitude, 
    CT_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=2ZN3TPSTZ2YHCDFULTDGFVGBX1YJL45HQ0LD3RCFOEMXCMM5&client_secret=3KYZWRDZC3JJNDBOS5V1MPTYUZPMGKNRI0CMKLHR125T0NHW&v=20210508&ll=43.6895743,-79.38315990000001&radius=600&limit=100'

# %%
result = requests.get(url).json()

# %%
# function that will return the category of the venue
def get_type(row):
    try:
        categories = row['categories']
    except:
        categories = row['venue.categories']
        
    if len(categories) == 0:
        return None
    else:
        return categories[0]['name']

# %%
venues = result['response']['groups'][0]['items']

# %% [markdown]
# ### Normalize JSON

# %%
nearby_venues = json_normalize(venues)
nearby_venues
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-4bc0d290920eb713dda1192c-0
# 1  e-0-4bf031dcf831c928eab401f2-1
# 2  e-0-4bb0200cf964a52090383ce3-2
# 3  e-0-4ee13f43b8f775b3731e5a0c-3
# 4  e-0-4ba17faef964a52012bc37e3-4
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 4  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#
#                    venue.id venue.location.address venue.location.cc  \
# 0  4bc0d290920eb713dda1192c     75 Rosehill Avenue                CA
# 1  4bf031dcf831c928eab401f2  200 Mount Pleasant Rd                CA
# 2  4bb0200cf964a52090383ce3     939 Eglinton Ave E                CA
# 3  4ee13f43b8f775b3731e5a0c               Adelaide                CA
# 4  4ba17faef964a52012bc37e3         Mount Pleasant                CA
#
#   venue.location.city venue.location.country venue.location.crossStreet  \
# 0             Toronto                 Canada                        NaN
# 1             Toronto                 Canada                        NaN
# 2             Toronto                 Canada                Brentcliffe
# 3             Toronto                 Canada                       York
# 4             Toronto                 Canada                        NaN
#
#    venue.location.distance                    venue.location.formattedAddress  \
# 0                      541           [75 Rosehill Avenue, Toronto ON, Canada]
# 1                      591  [200 Mount Pleasant Rd, Toronto ON M4T 2C4, Ca...
# 2                      533  [939 Eglinton Ave E (Brentcliffe), Toronto ON ...
# 3                      376              [Adelaide (York), Toronto ON, Canada]
# 4                      504               [Mount Pleasant, Toronto ON, Canada]
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 43.68630352898223...           43.686304
# 1  [{'label': 'display', 'lat': 43.68562946634291...           43.685629
# 2  [{'label': 'display', 'lat': 43.69300659993013...           43.693007
# 3  [{'label': 'display', 'lat': 43.6928156790476,...           43.692816
# 4  [{'label': 'display', 'lat': 43.6934103605598,...           43.693410
#
#    venue.location.lng venue.location.postalCode venue.location.state  \
# 0          -79.388133                       NaN                   ON
# 1          -79.388078                   M4T 2C4                   ON
# 2          -79.387781                   M4G 4E8                   ON
# 3          -79.384504                       NaN                   ON
# 4          -79.386506                       NaN                   ON
#
#               venue.name  venue.photos.count venue.photos.groups
# 0     Rosehill Reservoir                   0                  []
# 1  David A. Balfour Park                   0                  []
# 2           Pure Fitness                   0                  []
# 3                   Reds                   0                  []
# 4             On The Run                   0                  []

# %%
# firstly filtering columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]

# Moving on to the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_type, axis=1)

# cleaning columns for better representation
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                     name         categories        lat        lng
# 0     Rosehill Reservoir               Park  43.686304 -79.388133
# 1  David A. Balfour Park               Park  43.685629 -79.388078
# 2           Pure Fitness                Gym  43.693007 -79.387781
# 3                   Reds         Restaurant  43.692816 -79.384504
# 4             On The Run  Convenience Store  43.693410 -79.386506

# %%
print('Foursquare returned {} venues for Central Toronto'.format(nearby_venues.shape[0]))
# Out:
# Foursquare returned 5 venues for Central Toronto

# %%
def NearbyVenues(names, latitudes, longitudes, radius=500):

    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
    
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # getting url in result
        result = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in result])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues = NearbyVenues(names=df['Borough'],latitudes=df['Latitude'],longitudes=df['Longitude'])
# Out:
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# Scarborough
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# North York
# East York
# East York
# East Toronto
# East York
# East York
# East YorkEast Toronto
# East Toronto
# East Toronto
# East Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# North York
# Central Toronto
# Central Toronto
# Central Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown TorontoStn A PO Boxes25 The Esplanade
# Downtown Toronto
# North York
# North York
# York
# York
# Downtown Toronto
# West Toronto
# West Toronto
# West Toronto
# North York
# York
# York
# West Toronto
# West Toronto
# West Toronto
# Queen's Park
# MississaugaCanada Post Gateway Processing Centre
# East TorontoBusiness reply mail Processing Centre969 Eastern
# Etobicoke
# Etobicoke
# Etobicoke
# Etobicoke
# Etobicoke
# Etobicoke
# Etobicoke
# Etobicoke
# North York
# North York
# York
# Etobicoke
# Etobicoke
# Etobicoke
# EtobicokeNorthwest

# %%
print(venues.shape)
venues.head()
# Out:
# (2111, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Scarborough              43.806686              -79.194353
# 1  Scarborough              43.784535              -79.160497
# 2  Scarborough              43.784535              -79.160497
# 3  Scarborough              43.763573              -79.188711
# 4  Scarborough              43.763573              -79.188711
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0                      Wendy’s       43.807448       -79.199056
# 1  Great Shine Window Cleaning       43.783145       -79.157431
# 2        Royal Canadian Legion       43.782533       -79.163085
# 3               RBC Royal Bank       43.766790       -79.191151
# 4            G & G Electronics       43.765309       -79.191537
#
#          Venue Category
# 0  Fast Food Restaurant
# 1          Home Service
# 2                   Bar
# 3                  Bank
# 4     Electronics Store

# %% [markdown]
# ### Number of Venues per Neighborhood

# %%
venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Central Toronto                                                       105
# Downtown Toronto                                                     1100
# Downtown TorontoStn A PO Boxes25 The Esplanade                        100
# East Toronto                                                          103
# East TorontoBusiness reply mail Processing Cent...                     17
# East York                                                              70
# East YorkEast Toronto                                                   3
# Etobicoke                                                              69
# EtobicokeNorthwest                                                      5
# MississaugaCanada Post Gateway Processing Centre                       13
# North York                                                            232
# Queen's Park                                                           31
# Scarborough                                                            92
# West Toronto                                                          155
# York                                                                   16
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Central Toronto                                                        105
# Downtown Toronto                                                      1100
# Downtown TorontoStn A PO Boxes25 The Esplanade                         100
# East Toronto                                                           103
# East TorontoBusiness reply mail Processing Cent...                      17
# East York                                                               70
# East YorkEast Toronto                                                    3
# Etobicoke                                                               69
# EtobicokeNorthwest                                                       5
# MississaugaCanada Post Gateway Processing Centre                        13
# North York                                                             232
# Queen's Park                                                            31
# Scarborough                                                             92
# West Toronto                                                           155
# York                                                                    16
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Central Toronto                                       105             105
# Downtown Toronto                                     1100            1100
# Downtown TorontoStn A PO Boxes25 The Esplanade        100             100
# East Toronto                                          103             103
# East TorontoBusiness reply mail Processing Cent...     17              17
# East York                                              70              70
# East YorkEast Toronto                                   3               3
# Etobicoke                                              69              69
# EtobicokeNorthwest                                      5               5
# MississaugaCanada Post Gateway Processing Centre       13              13
# North York                                            232             232
# Queen's Park                                           31              31
# Scarborough                                            92              92
# West Toronto                                          155             155
# York                                                   16              16
#
#                                                     Venue Longitude  \
# Neighborhood
# Central Toronto                                                 105
# Downtown Toronto                                               1100
# Downtown TorontoStn A PO Boxes25 The Esplanade                  100
# East Toronto                                                    103
# East TorontoBusiness reply mail Processing Cent...               17
# East York                                                        70
# East YorkEast Toronto                                             3
# Etobicoke                                                        69
# EtobicokeNorthwest                                                5
# MississaugaCanada Post Gateway Processing Centre                 13
# North York                                                      232
# Queen's Park                                                     31
# Scarborough                                                      92
# West Toronto                                                    155
# York                                                             16
#
#                                                     Venue Category
# Neighborhood
# Central Toronto                                                105
# Downtown Toronto                                              1100
# Downtown TorontoStn A PO Boxes25 The Esplanade                 100
# East Toronto                                                   103
# East TorontoBusiness reply mail Processing Cent...              17
# East York                                                       70
# East YorkEast Toronto                                            3
# Etobicoke                                                       69
# EtobicokeNorthwest                                               5
# MississaugaCanada Post Gateway Processing Centre                13
# North York                                                     232
# Queen's Park                                                    31
# Scarborough                                                     92
# West Toronto                                                   155
# York                                                            16

# %%
print('There are {} unique venue categories in Toronto.'.format(len(venues['Venue Category'].unique())))
# Out:
# There are 269 unique venue categories in Toronto.

# %%
dummy = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
dummy['Neighborhood'] = venues['Neighborhood'] 

dummy.head()
print(dummy.shape)
groups = dummy.groupby('Neighborhood').mean().reset_index()
groups
# Out:
# (2111, 269)
#                                          Neighborhood  Accessories Store  \
# 0                                     Central Toronto            0.00000
# 1                                    Downtown Toronto            0.00000
# 2      Downtown TorontoStn A PO Boxes25 The Esplanade            0.00000
# 3                                        East Toronto            0.00000
# 4   East TorontoBusiness reply mail Processing Cen...            0.00000
# 5                                           East York            0.00000
# 6                               East YorkEast Toronto            0.00000
# 7                                           Etobicoke            0.00000
# 8                                  EtobicokeNorthwest            0.00000
# 9    MississaugaCanada Post Gateway Processing Centre            0.00000
# 10                                         North York            0.00431
# 11                                       Queen's Park            0.00000
# 12                                        Scarborough            0.00000
# 13                                       West Toronto            0.00000
# 14                                               York            0.00000
#
#     Adult Boutique   Airport  Airport Food Court  Airport Gate  \
# 0         0.000000  0.000000            0.000000      0.000000
# 1         0.000909  0.000909            0.000909      0.000909
# 2         0.000000  0.000000            0.000000      0.000000
# 3         0.000000  0.000000            0.000000      0.000000
# 4         0.000000  0.000000            0.000000      0.000000
# 5         0.000000  0.000000            0.000000      0.000000
# 6         0.000000  0.000000            0.000000      0.000000
# 7         0.000000  0.000000            0.000000      0.000000
# 8         0.000000  0.000000            0.000000      0.000000
# 9         0.000000  0.000000            0.000000      0.000000
# 10        0.000000  0.004310            0.000000      0.000000
# 11        0.000000  0.000000            0.000000      0.000000
# 12        0.000000  0.000000            0.000000      0.000000
# 13        0.000000  0.000000            0.000000      0.000000
# 14        0.000000  0.000000            0.000000      0.000000
#
#     Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0         0.000000         0.000000          0.000000             0.009524
# 1         0.001818         0.002727          0.001818             0.011818
# 2         0.000000         0.000000          0.000000             0.000000
# 3         0.000000         0.000000          0.000000             0.029126
# 4         0.000000         0.000000          0.000000             0.000000
# 5         0.000000         0.000000          0.000000             0.000000
# 6         0.000000         0.000000          0.000000             0.000000
# 7         0.000000         0.000000          0.000000             0.014493
# 8         0.000000         0.000000          0.000000             0.000000
# 9         0.000000         0.000000          0.000000             0.076923
# 10        0.000000         0.000000          0.000000             0.008621
# 11        0.000000         0.000000          0.000000             0.000000
# 12        0.000000         0.000000          0.000000             0.010870
# 13        0.000000         0.000000          0.000000             0.000000
# 14        0.000000         0.000000          0.000000             0.000000
#
#     ...  Truck Stop  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0   ...         0.0                       0.000000          0.000000
# 1   ...         0.0                       0.010909          0.001818
# 2   ...         0.0                       0.010000          0.000000
# 3   ...         0.0                       0.000000          0.000000
# 4   ...         0.0                       0.000000          0.000000
# 5   ...         0.0                       0.000000          0.000000
# 6   ...         0.0                       0.000000          0.000000
# 7   ...         0.0                       0.000000          0.000000
# 8   ...         0.2                       0.000000          0.000000
# 9   ...         0.0                       0.000000          0.000000
# 10  ...         0.0                       0.000000          0.004310
# 11  ...         0.0                       0.000000          0.000000
# 12  ...         0.0                       0.000000          0.000000
# 13  ...         0.0                       0.019355          0.000000
# 14  ...         0.0                       0.000000          0.000000
#
#     Video Store  Vietnamese Restaurant  Warehouse Store  Wine Bar  \
# 0      0.000000               0.009524         0.000000  0.000000
# 1      0.000000               0.003636         0.000000  0.007273
# 2      0.000000               0.000000         0.000000  0.000000
# 3      0.000000               0.000000         0.000000  0.000000
# 4      0.000000               0.000000         0.000000  0.000000
# 5      0.000000               0.000000         0.014286  0.000000
# 6      0.000000               0.000000         0.000000  0.000000
# 7      0.014493               0.000000         0.000000  0.000000
# 8      0.000000               0.000000         0.000000  0.000000
# 9      0.000000               0.000000         0.000000  0.000000
# 10     0.000000               0.008621         0.000000  0.000000
# 11     0.000000               0.000000         0.000000  0.000000
# 12     0.000000               0.010870         0.000000  0.000000
# 13     0.000000               0.012903         0.000000  0.006452
# 14     0.000000               0.000000         0.000000  0.000000
#
#     Wings Joint  Women's Store  Yoga Studio
# 0      0.000000       0.000000     0.009524
# 1      0.000000       0.000000     0.004545
# 2      0.000000       0.000000     0.010000
# 3      0.000000       0.000000     0.019417
# 4      0.000000       0.000000     0.058824
# 5      0.000000       0.000000     0.014286
# 6      0.000000       0.000000     0.000000
# 7      0.014493       0.000000     0.000000
# 8      0.000000       0.000000     0.000000
# 9      0.000000       0.000000     0.000000
# 10     0.000000       0.008621     0.000000
# 11     0.000000       0.000000     0.032258
# 12     0.000000       0.000000     0.000000
# 13     0.000000       0.000000     0.012903
# 14     0.000000       0.062500     0.000000
#
# [15 rows x 269 columns]

# %%
num_top_venues = 5

for g in groups['Neighborhood']:
    print("----"+g+"----")
    temp = groups[groups['Neighborhood'] == g].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Central Toronto----
#             venue  freq
# 0     Coffee Shop  0.08
# 1  Sandwich Place  0.07
# 2            Café  0.06
# 3     Pizza Place  0.06
# 4            Park  0.06
#
#
# ----Downtown Toronto----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.06
# 2           Restaurant  0.03
# 3                Hotel  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Downtown TorontoStn A PO Boxes25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1  Seafood Restaurant  0.04
# 2        Cocktail Bar  0.04
# 3              Bakery  0.03
# 4          Restaurant  0.03
#
#
# ----East Toronto----
#                 venue  freq
# 0    Greek Restaurant  0.08
# 1         Coffee Shop  0.07
# 2  Italian Restaurant  0.05
# 3             Brewery  0.04
# 4                Park  0.04
#
#
# ----East TorontoBusiness reply mail Processing Centre969 Eastern----
#            venue  freq
# 0    Yoga Studio  0.06
# 1  Auto Workshop  0.06
# 2    Pizza Place  0.06
# 3     Comic Shop  0.06
# 4     Restaurant  0.06
#
#
# ----East York----
#                     venue  freq
# 0             Coffee Shop  0.06
# 1                    Bank  0.06
# 2  Furniture / Home Store  0.04
# 3            Burger Joint  0.04
# 4            Intersection  0.04
#
#
# ----East YorkEast Toronto----
#                        venue  freq
# 0               Intersection  0.33
# 1                       Park  0.33
# 2          Convenience Store  0.33
# 3  Middle Eastern Restaurant  0.00
# 4        Moroccan Restaurant  0.00
#
#
# ----Etobicoke----
#             venue  freq
# 0     Pizza Place  0.12
# 1  Sandwich Place  0.07
# 2        Pharmacy  0.04
# 3            Café  0.04
# 4          Bakery  0.04
#
#
# ----EtobicokeNorthwest----
#                  venue  freq
# 0        Garden Center   0.2
# 1           Truck Stop   0.2
# 2                  Bar   0.2
# 3  Rental Car Location   0.2
# 4            Drugstore   0.2
#
#
# ----MississaugaCanada Post Gateway Processing Centre----
#                        venue  freq
# 0                Coffee Shop  0.23
# 1                      Hotel  0.15
# 2                Gas Station  0.08
# 3  Middle Eastern Restaurant  0.08
# 4              Burrito Place  0.08
#
#
# ----North York----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1        Clothing Store  0.05
# 2           Pizza Place  0.04
# 3            Restaurant  0.04
# 4  Fast Food Restaurant  0.03
#
#
# ----Queen's Park----
#               venue  freq
# 0       Coffee Shop  0.19
# 1  Sushi Restaurant  0.06
# 2       Yoga Studio  0.03
# 3    Sandwich Place  0.03
# 4          Beer Bar  0.03
#
#
# ----Scarborough----
#                   venue  freq
# 0           Coffee Shop  0.05
# 1  Fast Food Restaurant  0.05
# 2                Bakery  0.04
# 3                  Bank  0.04
# 4           Pizza Place  0.03
#
#
# ----West Toronto----
#                 venue  freq
# 0                Café  0.07
# 1                 Bar  0.06
# 2         Coffee Shop  0.05
# 3  Italian Restaurant  0.04
# 4          Restaurant  0.04
#
#
# ----York----
#                venue  freq
# 0               Park  0.19
# 1  Convenience Store  0.12
# 2              Trail  0.06
# 3               Pool  0.06
# 4        Coffee Shop  0.06

# %%
def common_venues(row, num_venues):
    categories = row.iloc[1:]
    categories_sorted = categories.sort_values(ascending=False)
    
    return categories_sorted.index.values[0:num_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create new columns according to the number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# new dataframe
venues_sorted = pd.DataFrame(columns=columns)
venues_sorted['Neighborhood'] = groups['Neighborhood']

for ind in np.arange(groups.shape[0]):
    venues_sorted.iloc[ind, 1:] = common_venues(groups.iloc[ind, :], num_top_venues)

venues_sorted
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                                     Central Toronto           Coffee Shop
# 1                                    Downtown Toronto           Coffee Shop
# 2      Downtown TorontoStn A PO Boxes25 The Esplanade           Coffee Shop
# 3                                        East Toronto      Greek Restaurant
# 4   East TorontoBusiness reply mail Processing Cen...           Yoga Studio
# 5                                           East York           Coffee Shop
# 6                               East YorkEast Toronto                  Park
# 7                                           Etobicoke           Pizza Place
# 8                                  EtobicokeNorthwest            Truck Stop
# 9    MississaugaCanada Post Gateway Processing Centre           Coffee Shop
# 10                                         North York           Coffee Shop
# 11                                       Queen's Park           Coffee Shop
# 12                                        Scarborough  Fast Food Restaurant
# 13                                       West Toronto                  Café
# 14                                               York                  Park
#
#    2nd Most Common Venue   3rd Most Common Venue 4th Most Common Venue  \
# 0         Sandwich Place                    Park           Pizza Place
# 1                   Café              Restaurant                 Hotel
# 2     Seafood Restaurant            Cocktail Bar                Bakery
# 3            Coffee Shop      Italian Restaurant               Brewery
# 4          Auto Workshop              Comic Shop                  Park
# 5                   Bank  Furniture / Home Store          Burger Joint
# 6           Intersection       Convenience Store             Drugstore
# 7         Sandwich Place                     Gym         Grocery Store
# 8    Rental Car Location           Garden Center             Drugstore
# 9                  Hotel           Burrito Place   American Restaurant
# 10        Clothing Store              Restaurant           Pizza Place
# 11      Sushi Restaurant             Yoga Studio                   Bar
# 12           Coffee Shop                  Bakery                  Bank
# 13                   Bar             Coffee Shop    Italian Restaurant
# 14     Convenience Store          Sandwich Place         Women's Store
#
#    5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0                   Café           Sushi Restaurant            Restaurant
# 1    Japanese Restaurant         Italian Restaurant                  Park
# 2                  Hotel                 Restaurant   Japanese Restaurant
# 3         Ice Cream Shop                       Park   American Restaurant
# 4            Pizza Place                    Butcher            Restaurant
# 5           Intersection                Pizza Place              Pharmacy
# 6         Discount Store        Distribution Center               Dog Run
# 7               Pharmacy       Fast Food Restaurant           Coffee Shop
# 8                    Bar           Doner Restaurant                 Diner
# 9           Intersection  Middle Eastern Restaurant           Gas Station
# 10                  Park       Fast Food Restaurant                  Bank
# 11              Beer Bar              Smoothie Shop        Sandwich Place
# 12        Breakfast Spot         Chinese Restaurant           Pizza Place
# 13            Restaurant                     Bakery        Breakfast Spot
# 14          Hockey Arena                      Field        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue         10th Most Common Venue
# 0                    Gym          Dessert Shop                            Pub
# 1                 Bakery        Clothing Store             Seafood Restaurant
# 2                   Café    Italian Restaurant                       Beer Bar
# 3                   Café                   Pub                         Bakery
# 4          Burrito Place               Brewery                     Skate Park
# 5             Restaurant    Athletics & Sports              Indian Restaurant
# 6       Doner Restaurant            Donut Shop            Dumpling Restaurant
# 7                   Café                Bakery                   Liquor Store
# 8         Discount Store   Distribution Center                        Dog Run
# 9         Sandwich Place   Fried Chicken Joint       Mediterranean Restaurant
# 10   Japanese Restaurant                  Café                  Grocery Store
# 11         Burrito Place                  Café          Portuguese Restaurant
# 12          Intersection     Convenience Store                       Pharmacy
# 13                  Park           Pizza Place  Vegetarian / Vegan Restaurant
# 14           Coffee Shop           Pizza Place                           Pool

# %%
# set number of clusters
clusters = 5

clustering = groups.drop('Neighborhood', 1)

# k-means clustering
kmeans = KMeans(n_clusters=clusters, random_state=0).fit(clustering)

# check cluster labels in the dataframe generated for each row
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 4, 0, 2, 3])

# %%
# set number of clusters
clusters = 5

clustering = groups.drop('Neighborhood', 1)

# k-means clustering
kmeans = KMeans(n_clusters=clusters, random_state=0).fit(clustering)

# check cluster labels in the dataframe generated for each row
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 4, 0, 2, 3])

# %%
merged = groups

# adding cluster labels
merged['Cluster Labels'] = kmeans.labels_

# merging data to add latitude/longitude for each neighborhood
merged = merged.join(venues_sorted.set_index('Neighborhood'), on='Neighborhood')

merged.head()
# Out:
#                                         Neighborhood  Accessories Store  \
# 0                                    Central Toronto                0.0
# 1                                   Downtown Toronto                0.0
# 2     Downtown TorontoStn A PO Boxes25 The Esplanade                0.0
# 3                                       East Toronto                0.0
# 4  East TorontoBusiness reply mail Processing Cen...                0.0
#
#    Adult Boutique   Airport  Airport Food Court  Airport Gate  Airport Lounge  \
# 0        0.000000  0.000000            0.000000      0.000000        0.000000
# 1        0.000909  0.000909            0.000909      0.000909        0.001818
# 2        0.000000  0.000000            0.000000      0.000000        0.000000
# 3        0.000000  0.000000            0.000000      0.000000        0.000000
# 4        0.000000  0.000000            0.000000      0.000000        0.000000
#
#    Airport Service  Airport Terminal  American Restaurant  ...  \
# 0         0.000000          0.000000             0.009524  ...
# 1         0.002727          0.001818             0.011818  ...
# 2         0.000000          0.000000             0.000000  ...
# 3         0.000000          0.000000             0.029126  ...
# 4         0.000000          0.000000             0.000000  ...
#
#    1st Most Common Venue  2nd Most Common Venue  3rd Most Common Venue  \
# 0            Coffee Shop         Sandwich Place                   Park
# 1            Coffee Shop                   Café             Restaurant
# 2            Coffee Shop     Seafood Restaurant           Cocktail Bar
# 3       Greek Restaurant            Coffee Shop     Italian Restaurant
# 4            Yoga Studio          Auto Workshop             Comic Shop
#
#    4th Most Common Venue  5th Most Common Venue  6th Most Common Venue  \
# 0            Pizza Place                   Café       Sushi Restaurant
# 1                  Hotel    Japanese Restaurant     Italian Restaurant
# 2                 Bakery                  Hotel             Restaurant
# 3                Brewery         Ice Cream Shop                   Park
# 4                   Park            Pizza Place                Butcher
#
#    7th Most Common Venue  8th Most Common Venue  9th Most Common Venue  \
# 0             Restaurant                    Gym           Dessert Shop
# 1                   Park                 Bakery         Clothing Store
# 2    Japanese Restaurant                   Café     Italian Restaurant
# 3    American Restaurant                   Café                    Pub
# 4             Restaurant          Burrito Place                Brewery
#
#    10th Most Common Venue
# 0                     Pub
# 1      Seafood Restaurant
# 2                Beer Bar
# 3                  Bakery
# 4              Skate Park
#
# [5 rows x 280 columns]
